# %%
# We have to create a hashtable now
# Please don't forget to make the keys lower letter and space is gapped with underscore
graph = {}
graph['addis_ababa'] = ['debre_birhan', 'ambo', 'adama']
graph['debre_birhan'] = ['debre_sina'] # Done
graph['ambo'] = ['nekemte', 'wolkite'] # Done
graph['adama'] = ['batu', 'matahara', 'assella'] # Done
graph['debre_sina'] = ['debre_markos', 'kemise'] # Done
graph['nekemte'] = ['gimbi', 'bedelle'] # Done
graph['wolkite'] = ['jimma', 'worabe'] # Done
graph['batu'] = ['butajirra', 'shashemene'] # Done
graph['matahara'] = ['awash'] # Done
graph['assella'] = ['assasa'] # Done
graph['debre_markos'] = ['finote_selam'] # Done
graph['kemise'] = ['dessie'] # Done
graph['gimbi'] = ['dembi_dollo'] # Done
graph['bedelle'] = ['gore', 'jimma'] # Done
graph['jimma'] = ['bonga', 'bedelle'] # Done
graph['worabe'] = ['butajirra', 'hossana'] # Done
graph['butajirra'] = ['worabe'] # Done
graph['shashemene'] = ['hawassa', 'dodolla'] # Done
graph['awash'] = ['gabi_rasu', 'chiro'] # Done
graph['assasa'] = ['dodolla'] # Done
graph['finote_selam'] = ['injibara', 'bahirdar'] # Done
graph['dessie'] = ['woldia'] # Done
graph['dembi_dollo'] = ['gambella', 'assosa'] # Done
graph['gore'] = ['gambella', 'tepi'] # Done
graph['jimma'].append('wolkite')
graph['bonga'] = ['tepi', 'mizan_teferi', 'dawro'] # Done
graph['bedelle'].append('nekemte')
graph['butajirra'].append('batu')
graph['hossana'] = ['shashemene', 'wolaita_sodo'] # Done
graph['worabe'].extend(['wolkite'])
graph['hawassa'] = ['dilla'] # Done
graph['dodolla'] = ['assasa', 'bale'] # Done
graph['gabi_rasu'] = ['samara'] # Done
graph['chiro'] = ['dire_dawa'] # Done
graph['dodolla'].append('shashemene')
graph['injibara'] = ['bahirdar'] # Done
graph['bahirdar'] = ['injibara', 'azezo', 'metekel', 'debre_tabor'] # Done
graph['woldia'] = ['lalibela', 'alamata', 'samara'] # Done
graph['gambella'] = ['gore'] # Done
graph['assosa'] = ['metekel'] # Done
graph['gambella'].append('dembi_dollo')
graph['tepi'] = ['mizan_teferi', 'bonga'] # Done
graph['tepi'].append('gore')
graph['mizan_teferi'] = ['tepi', 'basketo'] # Done
graph['dawro'] = ['basketo', 'wolaita_sodo'] # Done
graph['shashemene'].append('batu')
graph['wolaita_sodo'] = ['dawro', 'arba_minch'] # Done
graph['dilla'] = ['bule_hora'] # Done
graph['assasa'].append('assella')
graph['bale'] = ['goba', 'sof_oumer', 'liben'] # Done
graph['samara'] = ['alamata', 'woldia', 'fanti_rasu'] # Done
graph['dire_dawa'] = ['harar'] # Done
graph['bahirdar'].append('finote_selam')
graph['injibara'].append('finote_selam')
graph['azezo'] = ['gondar', 'metema'] # Done
graph['metekel'] = ['assosa'] # Done
graph['debre_tabor'] = ['lalibela'] # Done
graph['lalibela'] = ['debre_tabor', 'sekota'] # Done
graph['alamata'] = ['sekota', 'mekelle', 'samara'] # Done
graph['samara'].append('gabi_rasu')
graph['gore'].append('bedelle')
graph['metekel'].append('bahirdar')
graph['mizan_teferi'].append('bonga')
graph['bonga'].append('jimma')
graph['basketo'] = ['bench_maji', 'dawro', 'arba_minch'] # Done
graph['basketo'].append('mizan_teferi')
graph['wolaita_sodo'].append('hossana')
graph['dawro'].append('bonga')
graph['arba_minch'] = ['basketo', 'konso'] # Done
graph['bule_hora'] = ['yabello'] # Done
graph['goba'] = ['dega_habur', 'sof_oumer'] # Done
graph['sof_oumer'] = ['goba', 'kebri_dehar'] # Done
graph['liben'] = []
graph['alamata'].append('woldia')
graph['woldia'].append('dessie')
graph['fanti_rasu'] = ['kilbet_rasu'] # Done
graph['harar'] = ['babile'] # Done
graph['gondar'] = ['humera', 'debarke', 'metema'] # Done
graph['metema'] = ['khartum', 'gondar'] # Done
graph['assosa'].append('dembi_dollo')
graph['lalibela'].append('woldia')
graph['debre_tabor'].append('bahirdar')
graph['sekota'] = ['alamata', 'mekelle'] # Done
graph['sekota'].append('lalibela')
graph['mekelle'] = ['sekota', 'adigrat', 'adwa'] # Done
graph['bench_maji'] = ['juba']
graph['arba_minch'].append('wolaita_sodo')
graph['konso'] = ['yabello'] # Done
graph['yabello'] = ['konso', 'moyale'] # Done
graph['dega_habur'] = ['jigjiga', 'kebri_dehar'] # Done
graph['sof_oumer'].append('bale')
graph['goba'].append('bale')
graph['kebri_dehar'] = ['dega_habur', 'werder', 'gode'] # Done
graph['kilbet_rasu'] = []
graph['babile'] = ['jigjiga'] # Done
graph['humera'] = ['khartum', 'shire'] # Done
graph['debarke'] = ['shire'] # Done
graph['metema'].append('azezo')
graph['gondar'].append('azezo')
graph['mekelle'].append('alamata')
graph['adigrat'] = ['adwa', 'asmara'] # Done
graph['adwa'] = ['adigrat', 'axum'] # Done
graph['yabello'].append('bule_hora')
graph['konso'].append('arba_minch')
graph['moyale'] = ['nairobi'] # Done
graph['jigjiga'] = ['goba', 'kebri_dehar'] # Done
graph['dega_habur'].append('goba')
graph['werder'] = []
graph['khartum'] = []
graph['gode'] = ['dollo', 'mokadisho'] # Done
graph['shire'] = ['axum', 'debarke', 'humera'] # Done
graph['adwa'].append('mekelle')
graph['asmara'] = []
graph['adigrat'].append('mekelle')
graph['axum'] = ['shire', 'asmara'] # Done
graph['nairobi'] = []
graph['kebri_dehar'].append('sof_oumer')
graph['dollo'] = []
graph['mokadisho'] = []
graph['juba'] = []
graph['axum'].append('adwa')
graph['debarke'].append('gondar')
## Multiple checking should be avoided but anyway, the graph is clean
