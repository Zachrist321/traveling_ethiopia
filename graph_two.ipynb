# %%
graph = {}

graph['addis_ababa'] = {
    'debre_birhan': 5,
    'ambo': 5,
    'adama': 3
} # Done

graph['debre_birhan'] = {
    'debre_sina': 2
} # Done

graph['ambo'] = {
    'nekemte': 9,
    'wolkite': 6
} # Done

graph['adama'] = {
    'batu': 4,
    'matahara': 3,
    'assella': 4
} # Done

graph['debre_sina'] = {
    'debre_markos': 17,
    'kemise': 6
} # Done

graph['nekemte'] = {
    'gimbi': 4,
    'bedelle': 4
} # Done

graph['wolkite'] = {
    'jimma': 8,
    'worabe': 5
} # Done

graph['batu'] = {
    'butajirra': 2,
    'shashemene': 3
} # Done

graph['matahara'] = {
    'awash': 1
} # Done

graph['assella'] = {
    'assasa': 4
} # Done

graph['debre_markos'] = {
    'finote_selam': 3
} # Done

graph['kemise'] = {
    'dessie': 4
} # Done

graph['gimbi'] = {
    'dembi_dollo': 6
} # Done

graph['bedelle'] = {
    'gore': 6,
    'jimma': 7,
    'nekemte': 4
} # Done

graph['jimma'] = {
    'bonga': 4,
    'bedelle': 7,
    'wolkite': 8
} # Done

graph['worabe'] = {
    'butajirra': 2,
    'hossana': 2,
    'wolkite': 5
} # Done

graph['butajirra'] = {
    'worabe': 2,
    'batu': 2
} # Done

graph['shashemene'] = {
    'hawassa': 1,
    'dodolla': 3,
    'batu': 3,
    'hossana': 7
} # Done

graph['awash'] = {
    'gabi_rasu': 5,
    'chiro': 4
} # Done

graph['assasa'] = {
    'dodolla': 1,
    'assella': 4
} # Done

graph['finote_selam'] = {
    'injibara': 2,
    'bahirdar': 6
} # Done

graph['dessie'] = {
    'woldia': 6
} # Done

graph['dembi_dollo'] = {
    'gambella': 4,
    'assosa': 12
} # Done

graph['gore'] = {
    'gambella': 5,
    'tepi': 9,
    'bedelle': 6
} # Done

graph['bonga'] = {
    'tepi': 8,
    'mizan_teferi': 4,
    'dawro': 10,
    'jimma': 4
} # Done

graph['hossana'] = {
    'shashemene': 7,
    'wolaita_sodo': 4
} # Done

graph['hawassa'] = {
    'dilla': 3
} # Done

graph['dodolla'] = {
    'assasa': 1,
    'bale': 13,
    'shashemene': 3
} # Done

graph['gabi_rasu'] = {
    'samara': 9
} # Done

graph['chiro'] = {
    'dire_dawa': 8
} # Done

graph['injibara'] = {
    'bahirdar': 4,
    'finote_selam': 2
} # Done

graph['bahirdar'] = {
    'injibara': 4,
    'azezo': 7,
    'metekel': 11,
    'debre_tabor': 4,
    'finote_selam': 6
} # Done

graph['woldia'] = {
    'lalibela': 7,
    'alamata': 3,
    'samara': 8,
    'dessie': 6
} # Done

graph['gambella'] = {
    'dembi_dollo': 4,
    'gore': 5
} # Done

graph['assosa'] = {
    None
} ### Check it later

graph['tepi'] = {
    'mizan_teferi': 4,
    'bonga': 8,
    'gore': 9
} # Done

graph['mizan_teferi'] = {
    'tepi': 4,
    'bonga': 4
} # Done

graph['dawro'] = {
    'wolaita_sodo': 6,
    'bonga': 10
} # Done

graph['wolaita_sodo'] = {
    'dawro': 6,
    'arba_minch': 5,
    'hossana': 4
} # Done

graph['dilla'] = {
    'bule_hora': 4
} # Done

graph['bale'] = {
    'goba': 18,
    'sof_oumer': 23,
    'liben': 11
} # Done

graph['samara'] = {
    'alamata': 11,
    'woldia': 8,
    'fanti_rasu': 7,
    'gabi_rasu': 9
} # Done

graph['dire_dawa'] = {
    'harar': 4
} # Done

graph['azezo'] = {
    'gondar': 1,
    'metema': 7
} # Done

graph['metekel'] = {
    None
} # Check it later

graph['debre_tabor'] = {
    'lalibela': 8,
    'bahirdar': 4
} # Done

graph['lalibela'] = {
    'debre_tabor': 8,
    'sekota': 6,
    'woldia': 7
} # Done

graph['alamata'] = {
    'sekota': 6,
    'mekelle': 5,
    'samara': 11,
    'woldia': 3
} # Done

graph['sekota'] = {
    'alamata': 6,
    'mekelle': 9,
    'lalibela': 6
} # Done

graph['mekelle'] = {
    'sekota': 9,
    'adigrat': 4,
    'adwa': 7,
    'alamata': 5
} # Done

graph['bench_maji'] = {
    'juba': 22
} # Done

graph['arba_minch'] = {
    'basketo': 10,
    'konso': 4,
    'wolaita_sodo': 6
} # Done

graph['basketo'] = {
    'bench_maji': 5
} # Done

graph['bule_hora'] = {
    'yabello': 3
} # Done

graph['goba'] = {
    'dega_habur': 6,
    'sof_oumer': 6,
    'bale': 18,
    'babile': 28
} # Done

graph['sof_oumer'] = {
    'goba': 6,
    'gode': 23,
    'bale': 23
} # Done

graph['liben'] = {} # Done

graph['fanti_rasu'] = {
    'kilbet_rasu': 6
} # Done

graph['harar'] = {
    'babile': 2
} # Done
 
graph['gondar'] = {
    'humera': 9,
    'debarke': 4,
    'metema': 7,
    'azezo': 1
} # Done

graph['metema'] = {
    'khartum': 19,
    'gondar': 7,
    'azezo': 7
} # Done

graph['humera'] = {
    'gondar': 9,
    'shire': 8,
    'khartum': 21
} # Done

graph['debarke'] = {
    'shire': 7,
    'gondar': 4
} # Done

graph['adigrat'] = {
    'adwa': 4,
    'asmara': 6,
    'mekelle': 4
} # Done

graph['adwa'] = {
    'adigrat': 4,
    'axum': 1,
    'mekelle': 7
} # Done

graph['yabello'] = {
    'konso': 3,
    'moyale': 6,
    'bule_hora': 3
} # Done

graph['konso'] = {
    'yabello': 3,
    'arba_minch': 4
} # Done

graph['moyale'] = {
    'nairobi': 22
} # Done

graph['babile'] = {
    'harar': 2,
    'jigjiga': 3,
    'goba': 28
} # Done

graph['jigjiga'] = {
    'kebri_dehar': 6
} # Done

graph['dega_habur'] = {
    'jigjiga': 5,
    'kebri_dehar': 6,
} # Done

graph['werder'] = {}

graph['khartum'] = {}

graph['gode'] = {
    'dollo': 17,
    'mokadisho': 22
} # Done

graph['shire'] = {
    'axum': 2,
    'debarke': 7,
    'humera': 8
} # Done

graph['asmara'] = {} # Done

graph['axum'] = {
    'shire': 2,
    'asmara': 5,
    'adwa': 1
} # Done

graph['nairobi'] = {} # Done

graph['kebri_dehar'] = {
    'dega_habur': 6,
    'werder': 6,
    'gode': 5,
} # Done

graph['dollo'] = {}

graph['mokadisho'] = {}

graph['juba'] = {}
graph['kilbet_rasu'] = {}
graph['assela'] = {
    'assasa': 1
}
